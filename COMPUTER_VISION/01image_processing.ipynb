# %%
import cv2
import matplotlib .pyplot as plt
import numpy as np
# %matplotlib inline

# %%
img=cv2.imread('C:/6-computer_vision/00-puppy.jpg')

# %%
plt.imshow(img)

# %%
#this image is of color blue green and red converting to different colorspaces

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#converting into hsv()
img=cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2HLS)
plt.imshow(img)

# %% [markdown]
# BLending images
# blending images is actually quite simple .

# %%
import cv2

# %%
#two images
img1=cv2.imread('C:/6-computer_vision/dog_backpack.jpg')
img2=cv2.imread('C:/6-computer_vision/watermark_no_copy.png')

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1=cv2.resize(img1,(1200,1200))
img2=cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.3,gamma=0)#alpha ,beta are for changing the transparency

# %%
plt.imshow(blended)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0,gamma=0)
plt.imshow(blended)

# %%
blended=cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.7,gamma=0)
plt.imshow(blended)

# %% [markdown]
# thresholding in image processing is acommonly used technique that involves  converting an image into a binary image by separating the pixels into two classes based on their intensity values.the rocess involves selecting a threshold value,which acts as a boundary between the two classes.Pixels with intensity values above the threshold are assigned one value,usually white while losing those below the threshold are assigned another value usually black.threshoulding is useful for a range of applications,including image segmentation ,object detection,and in=mage binarization,,it is a simple yet powerful technique that can help you to simplify complex images and make them easier to analyze the process

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img=cv2.imread('C:/6-computer_vision/COMPUTER_VISION/rainbow.jpg')

# %%
plt.imshow(img)

# %%
#ADDING THE 0 FLAG
img1=cv2.imread()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-13da715d708a> in <module>
#       1 #ADDING THE 0 FLAG
# ----> 2 img1=cv2.imread()
#
# TypeError: Required argument 'filename' (pos 1) not found

# %%
ret,thresh1=cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap='gray')

# %%
ret,thresh2=cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret
plt.imshow(thresh3,cmap='gray')

# %%
ret,thresh3=cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret
plt.imshow(thresh3,cmap='gray')

# %%
ret,thresh4=cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret
plt.imshow(thresh3,cmap='gray')
