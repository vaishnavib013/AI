# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gorilla1=cv2.imread('gorilla.jpg')
show_gorilla=cv2.cvtColor(gorilla1,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(show_gorilla)

# %%
img=gorilla1

# %%
img.shape
# Out:
# (1295, 1955, 3)

# %%
#create a mask
mask=np.zeros(img.shape[:2],np.uint8)
mask[250:550,800:1250]=255

# %%
print(mask.dtype)#check mask datatype
mask=mask.astype('uint8')#convert mask to uint8 if necessary
# Out:
# uint8

# %%
show_rainbow_resized=cv2.resize(show_gorilla,(mask.shape[1],mask.shape[0]))

# %%
plt.imshow(mask,cmap='gray')

# %%
show_gorilla_resized=cv2.resize(show_gorilla,(mask.shape[1],mask.shape[0]))
masked_img=cv2.bitwise_and(img,img,mask=mask)
show_masked_img=cv2.bitwise_and(show_gorilla_resized,show_gorilla_resized,mask=mask)

# %%
plt.imshow(mask,cmap='gray')

# %%
masked_img=cv2.bitwise_and(img,img,mask=mask)
show_masked_img=cv2.bitwise_and(show_gorilla_resized,show_rainbow_resized,mask=mask)

# %%
plt.imshow(show_masked_img)
